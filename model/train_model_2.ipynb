# %%
# %pip install tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
import tensorflow as tf

batch_size = 64
train_datagen = ImageDataGenerator(featurewise_center=True,
                                  rescale = 1/255.0,
                                  rotation_range=15,
                                  brightness_range=(0.1,0.9),
                                  #zoom_range=0.4
                                  )

val_datagen = ImageDataGenerator(rescale = 1/255.0)

train_gen =  train_datagen.flow_from_directory("../data/train",
                                               target_size = (50,50),
                                               color_mode = "grayscale",
                                               class_mode = "categorical",
                                               batch_size = 128)
val_gen = val_datagen.flow_from_directory("../data/validation",
                                          target_size = (50,50),
                                          color_mode = "grayscale",
                                          class_mode = "categorical",
                                          batch_size = 128)
# Out:
# Requirement already satisfied: tensorflow in c:\users\roger\anaconda3\lib\site-packages (2.9.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: numpy>=1.20 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: packaging in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: setuptools in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\roger\anaconda3\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\roger\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\roger\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\roger\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\roger\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\roger\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\roger\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\roger\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\roger\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\roger\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\roger\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\roger\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\roger\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\roger\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\roger\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\roger\anaconda3\lib\site-packages (from packaging->tensorflow) (3.0.4)
# Found 3500 images belonging to 6 classes.
# Found 2958 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
import os
    
# size of the image: 48*48 pixels
pic_size = 50

# input path for the images
base_path = "../data/"

plt.figure(0, figsize=(12,20))
cpt = 0

for expression in os.listdir(base_path + "train/"):
    print(expression)
    for i in range(1,6):
        cpt = cpt + 1
        plt.subplot(7,5,cpt)
        img = load_img(base_path + "train/" + expression + "/" +os.listdir(base_path + "train/" + expression)[i], target_size=(pic_size, pic_size))
        plt.xlabel(expression)
        plt.imshow(img, cmap="gray")

plt.tight_layout()
# Out:
# empty
# handDown
# handUp
# paper
# rock
# scissors

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(32,(3,3), padding="same", activation="relu", input_shape=(50,50,1)))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.54))

model.add(keras.layers.Conv2D(64,(3,3), padding="same", activation="relu"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.7))

model.add(keras.layers.Conv2D(64,(3,3), padding="same", activation="relu"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.7))

model.add(keras.layers.Conv2D(64,(3,3), padding="same", activation="relu"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))
model.add(keras.layers.Dropout(0.6))


model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(64, activation="relu"))
model.add(keras.layers.Dropout(0.64))

model.add(keras.layers.Dense(6, activation="softmax"))
optimizer = keras.optimizers.Adam(lr =0.001)
model.compile(optimizer="rmsprop",
              loss="categorical_crossentropy",
              metrics=["accuracy"])
# Out:
# c:\Users\Roger\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

filepath="model/model2/weight_checkpoints/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(train_gen,
                   epochs=100,
                   validation_data = val_gen,
                   steps_per_epoch=train_gen.n//train_gen.batch_size,
                   validation_steps=val_gen.n//val_gen.batch_size,
                   callbacks = callbacks_list)
# Out:
# c:\Users\Roger\anaconda3\lib\site-packages\keras\preprocessing\image.py:1663: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7944 - accuracy: 0.2568
# Epoch 1: val_accuracy improved from -inf to 0.16950, saving model to model/model2/weight_checkpoints\weights-improvement-01-0.17.hdf5
# 27/27 [==============================] - 10s 322ms/step - loss: 1.7944 - accuracy: 0.2568 - val_loss: 1.7923 - val_accuracy: 0.1695
# Epoch 2/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7612 - accuracy: 0.2797
# Epoch 2: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 320ms/step - loss: 1.7612 - accuracy: 0.2797 - val_loss: 1.7930 - val_accuracy: 0.1692
# Epoch 3/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7541 - accuracy: 0.2835
# Epoch 3: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 320ms/step - loss: 1.7541 - accuracy: 0.2835 - val_loss: 1.7934 - val_accuracy: 0.1695
# Epoch 4/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7542 - accuracy: 0.2835
# Epoch 4: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 336ms/step - loss: 1.7542 - accuracy: 0.2835 - val_loss: 1.7945 - val_accuracy: 0.1692
# Epoch 5/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7435 - accuracy: 0.2841
# Epoch 5: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 338ms/step - loss: 1.7435 - accuracy: 0.2841 - val_loss: 1.7949 - val_accuracy: 0.1692
# Epoch 6/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7400 - accuracy: 0.2859
# Epoch 6: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 341ms/step - loss: 1.7400 - accuracy: 0.2859 - val_loss: 1.7964 - val_accuracy: 0.1695
# Epoch 7/100
# 27/27 [==============================] - ETA: 0s - loss: 1.7229 - accuracy: 0.2838
# Epoch 7: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 331ms/step - loss: 1.7229 - accuracy: 0.2838 - val_loss: 1.8002 - val_accuracy: 0.1695
# Epoch 8/100
# 27/27 [==============================] - ETA: 0s - loss: 1.6993 - accuracy: 0.2888
# Epoch 8: val_accuracy did not improve from 0.16950
# 27/27 [==============================] - 9s 342ms/step - loss: 1.6993 - accuracy: 0.2888 - val_loss: 1.8167 - val_accuracy: 0.1692
# Epoch 9/100
# 27/27 [==============================] - ETA: 0s - loss: 1.6718 - accuracy: 0.3001
# Epoch 9: val_accuracy improved from 0.16950 to 0.16984, saving model to model/model2/weight_checkpoints\weights-improvement-09-0.17.hdf5
# 27/27 [==============================] - 9s 337ms/step - loss: 1.6718 - accuracy: 0.3001 - val_loss: 1.8094 - val_accuracy: 0.1698
# Epoch 10/100
# 27/27 [==============================] - ETA: 0s - loss: 1.6593 - accuracy: 0.3114
# Epoch 10: val_accuracy improved from 0.16984 to 0.17289, saving model to model/model2/weight_checkpoints\weights-improvement-10-0.17.hdf5
# 27/27 [==============================] - 9s 343ms/step - loss: 1.6593 - accuracy: 0.3114 - val_loss: 1.8822 - val_accuracy: 0.1729
# Epoch 11/100
# 27/27 [==============================] - ETA: 0s - loss: 1.5839 - accuracy: 0.3455
# Epoch 11: val_accuracy improved from 0.17289 to 0.19124, saving model to model/model2/weight_checkpoints\weights-improvement-11-0.19.hdf5
# 27/27 [==============================] - 10s 355ms/step - loss: 1.5839 - accuracy: 0.3455 - val_loss: 1.8478 - val_accuracy: 0.1912
# Epoch 12/100
# 27/27 [==============================] - ETA: 0s - loss: 1.4912 - accuracy: 0.3858
# Epoch 12: val_accuracy improved from 0.19124 to 0.19871, saving model to model/model2/weight_checkpoints\weights-improvement-12-0.20.hdf5
# 27/27 [==============================] - 10s 369ms/step - loss: 1.4912 - accuracy: 0.3858 - val_loss: 1.9612 - val_accuracy: 0.1987
# Epoch 13/100
# 27/27 [==============================] - ETA: 0s - loss: 1.3723 - accuracy: 0.4502
# Epoch 13: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 10s 367ms/step - loss: 1.3723 - accuracy: 0.4502 - val_loss: 2.4781 - val_accuracy: 0.1437
# Epoch 14/100
# 27/27 [==============================] - ETA: 0s - loss: 1.2788 - accuracy: 0.4926
# Epoch 14: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 9s 335ms/step - loss: 1.2788 - accuracy: 0.4926 - val_loss: 2.3045 - val_accuracy: 0.1430
# Epoch 15/100
# 27/27 [==============================] - ETA: 0s - loss: 1.2365 - accuracy: 0.5039
# Epoch 15: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 9s 338ms/step - loss: 1.2365 - accuracy: 0.5039 - val_loss: 2.8013 - val_accuracy: 0.1172
# Epoch 16/100
# 27/27 [==============================] - ETA: 0s - loss: 1.2041 - accuracy: 0.5240
# Epoch 16: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 9s 336ms/step - loss: 1.2041 - accuracy: 0.5240 - val_loss: 2.5808 - val_accuracy: 0.1518
# Epoch 17/100
# 27/27 [==============================] - ETA: 0s - loss: 1.1439 - accuracy: 0.5528
# Epoch 17: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 9s 330ms/step - loss: 1.1439 - accuracy: 0.5528 - val_loss: 2.7918 - val_accuracy: 0.1586
# Epoch 18/100
# 27/27 [==============================] - ETA: 0s - loss: 1.1181 - accuracy: 0.5667
# Epoch 18: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 9s 351ms/step - loss: 1.1181 - accuracy: 0.5667 - val_loss: 3.0548 - val_accuracy: 0.1583
# Epoch 19/100
# 27/27 [==============================] - ETA: 0s - loss: 1.0694 - accuracy: 0.5970
# Epoch 19: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 14s 519ms/step - loss: 1.0694 - accuracy: 0.5970 - val_loss: 3.1799 - val_accuracy: 0.1647
# Epoch 20/100
# 27/27 [==============================] - ETA: 0s - loss: 1.0497 - accuracy: 0.6038
# Epoch 20: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 13s 483ms/step - loss: 1.0497 - accuracy: 0.6038 - val_loss: 3.0236 - val_accuracy: 0.1695
# Epoch 21/100
# 27/27 [==============================] - ETA: 0s - loss: 1.0025 - accuracy: 0.6127
# Epoch 21: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 13s 475ms/step - loss: 1.0025 - accuracy: 0.6127 - val_loss: 3.6114 - val_accuracy: 0.1559
# Epoch 22/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9926 - accuracy: 0.6234
# Epoch 22: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 13s 482ms/step - loss: 0.9926 - accuracy: 0.6234 - val_loss: 3.4359 - val_accuracy: 0.1569
# Epoch 23/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9850 - accuracy: 0.6364
# Epoch 23: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 13s 482ms/step - loss: 0.9850 - accuracy: 0.6364 - val_loss: 3.1653 - val_accuracy: 0.1766
# Epoch 24/100
# 27/27 [==============================] - ETA: 0s - loss: 1.0041 - accuracy: 0.6346
# Epoch 24: val_accuracy did not improve from 0.19871
# 27/27 [==============================] - 13s 501ms/step - loss: 1.0041 - accuracy: 0.6346 - val_loss: 3.1336 - val_accuracy: 0.1630
# Epoch 25/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9203 - accuracy: 0.6590
# Epoch 25: val_accuracy improved from 0.19871 to 0.20041, saving model to model/model2/weight_checkpoints\weights-improvement-25-0.20.hdf5
# 27/27 [==============================] - 13s 489ms/step - loss: 0.9203 - accuracy: 0.6590 - val_loss: 3.4947 - val_accuracy: 0.2004
# Epoch 26/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9300 - accuracy: 0.6637
# Epoch 26: val_accuracy did not improve from 0.20041
# 27/27 [==============================] - 14s 510ms/step - loss: 0.9300 - accuracy: 0.6637 - val_loss: 3.4880 - val_accuracy: 0.1990
# Epoch 27/100
# 27/27 [==============================] - ETA: 0s - loss: 0.9403 - accuracy: 0.6512
# Epoch 27: val_accuracy did not improve from 0.20041
# 27/27 [==============================] - 13s 480ms/step - loss: 0.9403 - accuracy: 0.6512 - val_loss: 3.4612 - val_accuracy: 0.1770
# Epoch 28/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8942 - accuracy: 0.6812
# Epoch 28: val_accuracy did not improve from 0.20041
# 27/27 [==============================] - 11s 416ms/step - loss: 0.8942 - accuracy: 0.6812 - val_loss: 3.4414 - val_accuracy: 0.1923
# Epoch 29/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8765 - accuracy: 0.6824
# Epoch 29: val_accuracy did not improve from 0.20041
# 27/27 [==============================] - 9s 329ms/step - loss: 0.8765 - accuracy: 0.6824 - val_loss: 3.5204 - val_accuracy: 0.1923
# Epoch 30/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8738 - accuracy: 0.6767
# Epoch 30: val_accuracy did not improve from 0.20041
# 27/27 [==============================] - 9s 323ms/step - loss: 0.8738 - accuracy: 0.6767 - val_loss: 3.6617 - val_accuracy: 0.1685
# Epoch 31/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8313 - accuracy: 0.7043
# Epoch 31: val_accuracy improved from 0.20041 to 0.20279, saving model to model/model2/weight_checkpoints\weights-improvement-31-0.20.hdf5
# 27/27 [==============================] - 9s 333ms/step - loss: 0.8313 - accuracy: 0.7043 - val_loss: 3.6370 - val_accuracy: 0.2028
# Epoch 32/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8604 - accuracy: 0.6892
# Epoch 32: val_accuracy did not improve from 0.20279
# 27/27 [==============================] - 9s 332ms/step - loss: 0.8604 - accuracy: 0.6892 - val_loss: 3.6909 - val_accuracy: 0.1702
# Epoch 33/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8299 - accuracy: 0.7023
# Epoch 33: val_accuracy improved from 0.20279 to 0.21196, saving model to model/model2/weight_checkpoints\weights-improvement-33-0.21.hdf5
# 27/27 [==============================] - 9s 326ms/step - loss: 0.8299 - accuracy: 0.7023 - val_loss: 3.6835 - val_accuracy: 0.2120
# Epoch 34/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8217 - accuracy: 0.7117
# Epoch 34: val_accuracy did not improve from 0.21196
# 27/27 [==============================] - 9s 331ms/step - loss: 0.8217 - accuracy: 0.7117 - val_loss: 4.0529 - val_accuracy: 0.2113
# Epoch 35/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8180 - accuracy: 0.7186
# Epoch 35: val_accuracy did not improve from 0.21196
# 27/27 [==============================] - 9s 333ms/step - loss: 0.8180 - accuracy: 0.7186 - val_loss: 3.7593 - val_accuracy: 0.2035
# Epoch 36/100
# 27/27 [==============================] - ETA: 0s - loss: 0.8079 - accuracy: 0.7186
# Epoch 36: val_accuracy did not improve from 0.21196
# 27/27 [==============================] - 9s 324ms/step - loss: 0.8079 - accuracy: 0.7186 - val_loss: 3.9007 - val_accuracy: 0.1933
# Epoch 37/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7705 - accuracy: 0.7295
# Epoch 37: val_accuracy improved from 0.21196 to 0.22758, saving model to model/model2/weight_checkpoints\weights-improvement-37-0.23.hdf5
# 27/27 [==============================] - 9s 334ms/step - loss: 0.7705 - accuracy: 0.7295 - val_loss: 4.0141 - val_accuracy: 0.2276
# Epoch 38/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7733 - accuracy: 0.7242
# Epoch 38: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 9s 344ms/step - loss: 0.7733 - accuracy: 0.7242 - val_loss: 3.7533 - val_accuracy: 0.2055
# Epoch 39/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7761 - accuracy: 0.7292
# Epoch 39: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 9s 319ms/step - loss: 0.7761 - accuracy: 0.7292 - val_loss: 3.9800 - val_accuracy: 0.1977
# Epoch 40/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7547 - accuracy: 0.7432
# Epoch 40: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 481ms/step - loss: 0.7547 - accuracy: 0.7432 - val_loss: 3.8753 - val_accuracy: 0.2024
# Epoch 41/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7436 - accuracy: 0.7429
# Epoch 41: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 491ms/step - loss: 0.7436 - accuracy: 0.7429 - val_loss: 4.3963 - val_accuracy: 0.1685
# Epoch 42/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7342 - accuracy: 0.7444
# Epoch 42: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 481ms/step - loss: 0.7342 - accuracy: 0.7444 - val_loss: 3.8494 - val_accuracy: 0.1946
# Epoch 43/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7241 - accuracy: 0.7485
# Epoch 43: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 487ms/step - loss: 0.7241 - accuracy: 0.7485 - val_loss: 4.2252 - val_accuracy: 0.2181
# Epoch 44/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7159 - accuracy: 0.7518
# Epoch 44: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 483ms/step - loss: 0.7159 - accuracy: 0.7518 - val_loss: 3.8245 - val_accuracy: 0.1926
# Epoch 45/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.7500
# Epoch 45: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 495ms/step - loss: 0.7195 - accuracy: 0.7500 - val_loss: 3.7072 - val_accuracy: 0.2249
# Epoch 46/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7255 - accuracy: 0.7527
# Epoch 46: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 485ms/step - loss: 0.7255 - accuracy: 0.7527 - val_loss: 4.0505 - val_accuracy: 0.1963
# Epoch 47/100
# 27/27 [==============================] - ETA: 0s - loss: 0.7028 - accuracy: 0.7595
# Epoch 47: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 477ms/step - loss: 0.7028 - accuracy: 0.7595 - val_loss: 3.6959 - val_accuracy: 0.2065
# Epoch 48/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.7761
# Epoch 48: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 496ms/step - loss: 0.6650 - accuracy: 0.7761 - val_loss: 3.5530 - val_accuracy: 0.2123
# Epoch 49/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6568 - accuracy: 0.7761
# Epoch 49: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 13s 485ms/step - loss: 0.6568 - accuracy: 0.7761 - val_loss: 4.4084 - val_accuracy: 0.1974
# Epoch 50/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6753 - accuracy: 0.7675
# Epoch 50: val_accuracy did not improve from 0.22758
# 27/27 [==============================] - 11s 397ms/step - loss: 0.6753 - accuracy: 0.7675 - val_loss: 3.6823 - val_accuracy: 0.2171
# Epoch 51/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6531 - accuracy: 0.7761
# Epoch 51: val_accuracy improved from 0.22758 to 0.25543, saving model to model/model2/weight_checkpoints\weights-improvement-51-0.26.hdf5
# 27/27 [==============================] - 9s 330ms/step - loss: 0.6531 - accuracy: 0.7761 - val_loss: 3.8120 - val_accuracy: 0.2554
# Epoch 52/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.7823
# Epoch 52: val_accuracy did not improve from 0.25543
# 27/27 [==============================] - 9s 321ms/step - loss: 0.6563 - accuracy: 0.7823 - val_loss: 4.9479 - val_accuracy: 0.1967
# Epoch 53/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7859
# Epoch 53: val_accuracy did not improve from 0.25543
# 27/27 [==============================] - 9s 332ms/step - loss: 0.6295 - accuracy: 0.7859 - val_loss: 4.4720 - val_accuracy: 0.2035
# Epoch 54/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.7708
# Epoch 54: val_accuracy did not improve from 0.25543
# 27/27 [==============================] - 9s 333ms/step - loss: 0.6956 - accuracy: 0.7708 - val_loss: 3.8294 - val_accuracy: 0.1980
# Epoch 55/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6059 - accuracy: 0.7983
# Epoch 55: val_accuracy improved from 0.25543 to 0.26596, saving model to model/model2/weight_checkpoints\weights-improvement-55-0.27.hdf5
# 27/27 [==============================] - 9s 329ms/step - loss: 0.6059 - accuracy: 0.7983 - val_loss: 3.9427 - val_accuracy: 0.2660
# Epoch 56/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6313 - accuracy: 0.7933
# Epoch 56: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 9s 321ms/step - loss: 0.6313 - accuracy: 0.7933 - val_loss: 4.2914 - val_accuracy: 0.2079
# Epoch 57/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6234 - accuracy: 0.8010
# Epoch 57: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 9s 330ms/step - loss: 0.6234 - accuracy: 0.8010 - val_loss: 3.9063 - val_accuracy: 0.2398
# Epoch 58/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6153 - accuracy: 0.7918
# Epoch 58: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 9s 326ms/step - loss: 0.6153 - accuracy: 0.7918 - val_loss: 4.3076 - val_accuracy: 0.2126
# Epoch 59/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.7980
# Epoch 59: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 9s 325ms/step - loss: 0.6198 - accuracy: 0.7980 - val_loss: 3.9256 - val_accuracy: 0.2391
# Epoch 60/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5880 - accuracy: 0.8019
# Epoch 60: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 9s 328ms/step - loss: 0.5880 - accuracy: 0.8019 - val_loss: 3.9983 - val_accuracy: 0.2337
# Epoch 61/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5801 - accuracy: 0.8043
# Epoch 61: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 12s 441ms/step - loss: 0.5801 - accuracy: 0.8043 - val_loss: 4.1939 - val_accuracy: 0.2235
# Epoch 62/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.8022
# Epoch 62: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 13s 493ms/step - loss: 0.5878 - accuracy: 0.8022 - val_loss: 4.3084 - val_accuracy: 0.2340
# Epoch 63/100
# 27/27 [==============================] - ETA: 0s - loss: 0.6085 - accuracy: 0.7969
# Epoch 63: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 13s 487ms/step - loss: 0.6085 - accuracy: 0.7969 - val_loss: 4.3222 - val_accuracy: 0.2147
# Epoch 64/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5905 - accuracy: 0.8055
# Epoch 64: val_accuracy did not improve from 0.26596
# 27/27 [==============================] - 13s 487ms/step - loss: 0.5905 - accuracy: 0.8055 - val_loss: 4.2970 - val_accuracy: 0.2201
# Epoch 65/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5847 - accuracy: 0.8034
# Epoch 65: val_accuracy improved from 0.26596 to 0.28091, saving model to model/model2/weight_checkpoints\weights-improvement-65-0.28.hdf5
# 27/27 [==============================] - 13s 485ms/step - loss: 0.5847 - accuracy: 0.8034 - val_loss: 4.1309 - val_accuracy: 0.2809
# Epoch 66/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5527 - accuracy: 0.8227
# Epoch 66: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 487ms/step - loss: 0.5527 - accuracy: 0.8227 - val_loss: 4.3504 - val_accuracy: 0.1878
# Epoch 67/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5360 - accuracy: 0.8238
# Epoch 67: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 490ms/step - loss: 0.5360 - accuracy: 0.8238 - val_loss: 4.3258 - val_accuracy: 0.2486
# Epoch 68/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5664 - accuracy: 0.8123
# Epoch 68: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 488ms/step - loss: 0.5664 - accuracy: 0.8123 - val_loss: 4.3662 - val_accuracy: 0.2225
# Epoch 69/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5248 - accuracy: 0.8235
# Epoch 69: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 489ms/step - loss: 0.5248 - accuracy: 0.8235 - val_loss: 4.2221 - val_accuracy: 0.2317
# Epoch 70/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5609 - accuracy: 0.8117
# Epoch 70: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 489ms/step - loss: 0.5609 - accuracy: 0.8117 - val_loss: 4.2527 - val_accuracy: 0.2368
# Epoch 71/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4992 - accuracy: 0.8390
# Epoch 71: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 14s 504ms/step - loss: 0.4992 - accuracy: 0.8390 - val_loss: 4.2167 - val_accuracy: 0.2408
# Epoch 72/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5425 - accuracy: 0.8218
# Epoch 72: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 10s 374ms/step - loss: 0.5425 - accuracy: 0.8218 - val_loss: 4.0649 - val_accuracy: 0.2408
# Epoch 73/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5377 - accuracy: 0.8224
# Epoch 73: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 333ms/step - loss: 0.5377 - accuracy: 0.8224 - val_loss: 4.4455 - val_accuracy: 0.2463
# Epoch 74/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5169 - accuracy: 0.8310
# Epoch 74: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 321ms/step - loss: 0.5169 - accuracy: 0.8310 - val_loss: 4.4045 - val_accuracy: 0.2249
# Epoch 75/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4818 - accuracy: 0.8402
# Epoch 75: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 330ms/step - loss: 0.4818 - accuracy: 0.8402 - val_loss: 4.5349 - val_accuracy: 0.2201
# Epoch 76/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.8354
# Epoch 76: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 321ms/step - loss: 0.5025 - accuracy: 0.8354 - val_loss: 4.2874 - val_accuracy: 0.2385
# Epoch 77/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.8387
# Epoch 77: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 341ms/step - loss: 0.4686 - accuracy: 0.8387 - val_loss: 4.1940 - val_accuracy: 0.2456
# Epoch 78/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5186 - accuracy: 0.8360
# Epoch 78: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 350ms/step - loss: 0.5186 - accuracy: 0.8360 - val_loss: 4.0454 - val_accuracy: 0.2340
# Epoch 79/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4819 - accuracy: 0.8366
# Epoch 79: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 326ms/step - loss: 0.4819 - accuracy: 0.8366 - val_loss: 5.0420 - val_accuracy: 0.2082
# Epoch 80/100
# 27/27 [==============================] - ETA: 0s - loss: 0.5101 - accuracy: 0.8295
# Epoch 80: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 329ms/step - loss: 0.5101 - accuracy: 0.8295 - val_loss: 3.8968 - val_accuracy: 0.2306
# Epoch 81/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4816 - accuracy: 0.8348
# Epoch 81: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 324ms/step - loss: 0.4816 - accuracy: 0.8348 - val_loss: 4.2769 - val_accuracy: 0.2259
# Epoch 82/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4703 - accuracy: 0.8410
# Epoch 82: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 328ms/step - loss: 0.4703 - accuracy: 0.8410 - val_loss: 4.1878 - val_accuracy: 0.2531
# Epoch 83/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4838 - accuracy: 0.8413
# Epoch 83: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 11s 429ms/step - loss: 0.4838 - accuracy: 0.8413 - val_loss: 4.6163 - val_accuracy: 0.2028
# Epoch 84/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4581 - accuracy: 0.8493
# Epoch 84: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 479ms/step - loss: 0.4581 - accuracy: 0.8493 - val_loss: 4.3280 - val_accuracy: 0.2401
# Epoch 85/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4644 - accuracy: 0.8437
# Epoch 85: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 499ms/step - loss: 0.4644 - accuracy: 0.8437 - val_loss: 3.6832 - val_accuracy: 0.2374
# Epoch 86/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4694 - accuracy: 0.8473
# Epoch 86: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 488ms/step - loss: 0.4694 - accuracy: 0.8473 - val_loss: 3.5666 - val_accuracy: 0.2439
# Epoch 87/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.8514
# Epoch 87: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 493ms/step - loss: 0.4828 - accuracy: 0.8514 - val_loss: 4.1643 - val_accuracy: 0.2378
# Epoch 88/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4513 - accuracy: 0.8574
# Epoch 88: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 488ms/step - loss: 0.4513 - accuracy: 0.8574 - val_loss: 4.5801 - val_accuracy: 0.2092
# Epoch 89/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.8499
# Epoch 89: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 491ms/step - loss: 0.4466 - accuracy: 0.8499 - val_loss: 4.5965 - val_accuracy: 0.2072
# Epoch 90/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.8517
# Epoch 90: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 14s 508ms/step - loss: 0.4482 - accuracy: 0.8517 - val_loss: 4.5723 - val_accuracy: 0.2266
# Epoch 91/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.8630
# Epoch 91: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 13s 493ms/step - loss: 0.4315 - accuracy: 0.8630 - val_loss: 4.0868 - val_accuracy: 0.2459
# Epoch 92/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4356 - accuracy: 0.8606
# Epoch 92: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 16s 596ms/step - loss: 0.4356 - accuracy: 0.8606 - val_loss: 4.4066 - val_accuracy: 0.2385
# Epoch 93/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4381 - accuracy: 0.8594
# Epoch 93: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 344ms/step - loss: 0.4381 - accuracy: 0.8594 - val_loss: 3.8658 - val_accuracy: 0.2605
# Epoch 94/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.8556
# Epoch 94: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 326ms/step - loss: 0.4541 - accuracy: 0.8556 - val_loss: 4.3939 - val_accuracy: 0.2588
# Epoch 95/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4205 - accuracy: 0.8657
# Epoch 95: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 341ms/step - loss: 0.4205 - accuracy: 0.8657 - val_loss: 4.8727 - val_accuracy: 0.2306
# Epoch 96/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4326 - accuracy: 0.8600
# Epoch 96: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 330ms/step - loss: 0.4326 - accuracy: 0.8600 - val_loss: 4.4587 - val_accuracy: 0.2296
# Epoch 97/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4264 - accuracy: 0.8665
# Epoch 97: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 334ms/step - loss: 0.4264 - accuracy: 0.8665 - val_loss: 4.4520 - val_accuracy: 0.2252
# Epoch 98/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4625 - accuracy: 0.8493
# Epoch 98: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 10s 365ms/step - loss: 0.4625 - accuracy: 0.8493 - val_loss: 4.3417 - val_accuracy: 0.2381
# Epoch 99/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4408 - accuracy: 0.8630
# Epoch 99: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 322ms/step - loss: 0.4408 - accuracy: 0.8630 - val_loss: 4.3089 - val_accuracy: 0.2378
# Epoch 100/100
# 27/27 [==============================] - ETA: 0s - loss: 0.4282 - accuracy: 0.8648
# Epoch 100: val_accuracy did not improve from 0.28091
# 27/27 [==============================] - 9s 329ms/step - loss: 0.4282 - accuracy: 0.8648 - val_loss: 4.4563 - val_accuracy: 0.2120

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.grid()
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %%
model_json= model.to_json()
with open("model2/model2.json","w") as json_file:
    json_file.write(model_json)
print('model saved')
# Out:
# model saved

# %%
model.save_weights("model2/best_weights.h5")
